# %%
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical

import os
import datetime

# %load_ext tensorboard

import matplotlib.pyplot as plt
from skimage import color, exposure

from sklearn.metrics import accuracy_score

from hyperopt import hp, STATUS_OK, tpe, Trials, fmin
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
cd '/content/drive/My Drive/Colab Notebooks/Matrix/dw_matrix-/matrix_tree'
# Out:
# /content/drive/My Drive/Colab Notebooks/Matrix/dw_matrix-/matrix_tree

# %%
train = pd.read_pickle('data/train.p')
test = pd.read_pickle('data/test.p')

X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

# %%
if y_train.ndim == 1: y_train = to_categorical(y_train)
if y_test.ndim == 1: y_test = to_categorical(y_test)

# %%
input_shape = X_train.shape[1:]
num_classes = y_train.shape[1]

# %%
def train_model(model, X_train, y_train, params_fit={}):
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

  logdir = os.path.join('logs', datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

  model.fit(X_train, 
            y_train,
            batch_size=params_fit.get('batch_size', 128),
            epochs=params_fit.get('epochs', 5),
            verbose=params_fit.get('verbose', 1),
            validation_data=params_fit.get('validation_data', (X_train, y_train)),
            callbacks=[tensorboard_callback]
            )
  
  return model

def predict(model_trained, X_test, y_test, scoring=accuracy_score):

  y_test_norm = np.argmax(y_test, axis=1)

  y_pred_prob = model_trained.predict(X_test)
  y_pred = np.argmax(y_pred_prob, axis=1)

  return scoring(y_test_norm, y_pred)

# %%
def get_cnn_v5(input_shape, num_classes):
  return Sequential([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=input_shape),
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same'),
    MaxPool2D(),
    Dropout(0.3),

    Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(0.3),

    Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(0.3),

    Flatten(),
    
    Dense(1024, activation='relu'),
    Dropout(0.3),

    Dense(1024, activation='relu'),
    Dropout(0.3),

    Dense(num_classes, activation='softmax')  
  ])

# %%
model = get_cnn_v5(input_shape, num_classes)
model_trained = train_model(model, X_train, y_train)
predict(model_trained, X_test, y_test)
# Out:
# Epoch 1/5
#   2/272 [..............................] - ETA: 12:37 - loss: 5.2373 - accuracy: 0.0469WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (2.797168). Check your callbacks.
# 272/272 [==============================] - 11s 42ms/step - loss: 2.2758 - accuracy: 0.3525 - val_loss: 0.5569 - val_accuracy: 0.8142
# Epoch 2/5
# 272/272 [==============================] - 6s 20ms/step - loss: 0.4415 - accuracy: 0.8598 - val_loss: 0.1713 - val_accuracy: 0.9470
# Epoch 3/5
# 272/272 [==============================] - 6s 20ms/step - loss: 0.2137 - accuracy: 0.9363 - val_loss: 0.0576 - val_accuracy: 0.9816
# Epoch 4/5
# 272/272 [==============================] - 5s 20ms/step - loss: 0.1446 - accuracy: 0.9590 - val_loss: 0.0283 - val_accuracy: 0.9916
# Epoch 5/5
# 272/272 [==============================] - 5s 20ms/step - loss: 0.0956 - accuracy: 0.9728 - val_loss: 0.0367 - val_accuracy: 0.9891
# 0.9616780045351474

# %%
model_trained.evaluate(X_test, y_test)[1]
# Out:
# 138/138 [==============================] - 1s 4ms/step - loss: 0.1453 - accuracy: 0.9617
# 0.9616780281066895

# %%
def get_model(params):
  return Sequential([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=input_shape),
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_one']),

    Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_two']),

    Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_tree']),

    Flatten(),
    
    Dense(1024, activation='relu'),
    Dropout(params['dropout_dense_block_one']),

    Dense(1024, activation='relu'),
    Dropout(params['dropout_dense_block_two']),

    Dense(num_classes, activation='softmax')  
  ])

# %%
def func_obj(params):
  model = get_model(params)
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

  model.fit(
      X_train, 
      y_train,
      batch_size= int(params.get('batch_size', 128)),
      epochs= 5,
      verbose=0,
     
  )
  
  score = model.evaluate(X_test, y_test, verbose=0)
  accuracy = score[1]
  print(params, 'accuracy={}'.format(accuracy))

  return {'loss':-accuracy, 'status': STATUS_OK, 'model': model}

# %%
space = {
    'batch_size': hp.quniform('batch_size', 100, 200, 10),
    'dropout_cnn_block_one': hp.uniform('dropout_cnn_block_one', 0.3, 0.5),
    'dropout_cnn_block_two': hp.uniform('dropout_cnn_block_two', 0.3, 0.5),
    'dropout_cnn_block_tree': hp.uniform('dropout_cnn_block_tree', 0.3, 0.5),

    'dropout_dense_block_one': hp.uniform('dropout_dense_block_one', 0.3, 0.7),
    'dropout_dense_block_two': hp.uniform('dropout_dense_block_two', 0.3, 0.7)
}

best = fmin(
    func_obj,
    space,
    tpe.suggest,
    30,
    Trials()
    
)
# Out:
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.3036663417052082, 'dropout_cnn_block_tree': 0.3311630030728248, 'dropout_cnn_block_two': 0.322642546910468, 'dropout_dense_block_one': 0.4491911603443769, 'dropout_dense_block_two': 0.3613292665554358}
# accuracy=0.9519274234771729
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.3911672615234459, 'dropout_cnn_block_tree': 0.43714286235718336, 'dropout_cnn_block_two': 0.4059341431412958, 'dropout_dense_block_one': 0.6341260149400714, 'dropout_dense_block_two': 0.3387617762448081}
# accuracy=0.9292517304420471
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.44608647448138933, 'dropout_cnn_block_tree': 0.44294404755901473, 'dropout_cnn_block_two': 0.40693491748056176, 'dropout_dense_block_one': 0.5485936824234372, 'dropout_dense_block_two': 0.41515793256112205}
# accuracy=0.9337868690490723
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.43828371047720627, 'dropout_cnn_block_tree': 0.4832936106645897, 'dropout_cnn_block_two': 0.4567176461314178, 'dropout_dense_block_one': 0.6083692571368328, 'dropout_dense_block_two': 0.6970792489852699}
# accuracy=0.7931972742080688
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.3156073522039517, 'dropout_cnn_block_tree': 0.36520875725432644, 'dropout_cnn_block_two': 0.3177862148292287, 'dropout_dense_block_one': 0.6138878695632988, 'dropout_dense_block_two': 0.5976502294688675}
# accuracy=0.9573696255683899
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.44578371700393427, 'dropout_cnn_block_tree': 0.3319841086137979, 'dropout_cnn_block_two': 0.3172624660931758, 'dropout_dense_block_one': 0.4915763376621328, 'dropout_dense_block_two': 0.6337653173935327}
# accuracy=0.9133786559104919
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.3430523321687942, 'dropout_cnn_block_tree': 0.47764758552249154, 'dropout_cnn_block_two': 0.4266292647391274, 'dropout_dense_block_one': 0.5824100374078712, 'dropout_dense_block_two': 0.623110063981335}
# accuracy=0.8396825194358826
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.31751609180353896, 'dropout_cnn_block_tree': 0.4124349369394969, 'dropout_cnn_block_two': 0.3210541053935508, 'dropout_dense_block_one': 0.3367752172247436, 'dropout_dense_block_two': 0.4939863730751539}
# accuracy=0.9668934345245361
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.3293579145971679, 'dropout_cnn_block_tree': 0.445355313994509, 'dropout_cnn_block_two': 0.40156832999721126, 'dropout_dense_block_one': 0.4983851614972542, 'dropout_dense_block_two': 0.6497168495598094}
# accuracy=0.9312925338745117
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.3139376982758056, 'dropout_cnn_block_tree': 0.3186987441312253, 'dropout_cnn_block_two': 0.40869181976429647, 'dropout_dense_block_one': 0.6294694966296925, 'dropout_dense_block_two': 0.46586470991480305}
# accuracy=0.9285714030265808
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.39707519108538636, 'dropout_cnn_block_tree': 0.42593246106532595, 'dropout_cnn_block_two': 0.3244901369455549, 'dropout_dense_block_one': 0.5016347587602101, 'dropout_dense_block_two': 0.6810301627912296}
# accuracy=0.9575963616371155
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.41033488454908024, 'dropout_cnn_block_tree': 0.4161319083782654, 'dropout_cnn_block_two': 0.31445735652294377, 'dropout_dense_block_one': 0.6620298022600181, 'dropout_dense_block_two': 0.5394882730311134}
# accuracy=0.9088435173034668
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.46517948044954693, 'dropout_cnn_block_tree': 0.301156043255329, 'dropout_cnn_block_two': 0.414181611637673, 'dropout_dense_block_one': 0.5579529002680164, 'dropout_dense_block_two': 0.5653987709670876}
# accuracy=0.9401360750198364
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.43556517434941916, 'dropout_cnn_block_tree': 0.48940134469746754, 'dropout_cnn_block_two': 0.30948330701393745, 'dropout_dense_block_one': 0.6662571863946896, 'dropout_dense_block_two': 0.34144672525511904}
# accuracy=0.918367326259613
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.3587415810164062, 'dropout_cnn_block_tree': 0.47805837494297193, 'dropout_cnn_block_two': 0.45961697920599454, 'dropout_dense_block_one': 0.4006924276990391, 'dropout_dense_block_two': 0.3197056696197594}
# accuracy=0.9092970490455627
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.3593353123293148, 'dropout_cnn_block_tree': 0.33928586728337157, 'dropout_cnn_block_two': 0.446225398204552, 'dropout_dense_block_one': 0.6573062435670353, 'dropout_dense_block_two': 0.5765205577548065}
# accuracy=0.8999999761581421
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.4374345910469192, 'dropout_cnn_block_tree': 0.3641216329718201, 'dropout_cnn_block_two': 0.3821916464006469, 'dropout_dense_block_one': 0.5559137341082414, 'dropout_dense_block_two': 0.4628914946113046}
# accuracy=0.9181405901908875
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.4912694209049651, 'dropout_cnn_block_tree': 0.3547832326208857, 'dropout_cnn_block_two': 0.3765753811893836, 'dropout_dense_block_one': 0.3942932543484945, 'dropout_dense_block_two': 0.5482833188510547}
# accuracy=0.9038548469543457
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.45977571218841334, 'dropout_cnn_block_tree': 0.36186587072596876, 'dropout_cnn_block_two': 0.41082579609417835, 'dropout_dense_block_one': 0.3636924882085457, 'dropout_dense_block_two': 0.4658124669278618}
# accuracy=0.9267573952674866
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.4682851329522235, 'dropout_cnn_block_tree': 0.33098426125466107, 'dropout_cnn_block_two': 0.3437554077709188, 'dropout_dense_block_one': 0.36960550397651326, 'dropout_dense_block_two': 0.4629859152695346}
# accuracy=0.960544228553772
# {'batch_size': 170.0, 'dropout_cnn_block_one': 0.49793068226380227, 'dropout_cnn_block_tree': 0.3927789720949656, 'dropout_cnn_block_two': 0.3492314079630614, 'dropout_dense_block_one': 0.30048738524259033, 'dropout_dense_block_two': 0.40267072718546515}
# accuracy=0.9507936239242554
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.47990407029027343, 'dropout_cnn_block_tree': 0.3900796842609417, 'dropout_cnn_block_two': 0.3491894180981706, 'dropout_dense_block_one': 0.3022039735167183, 'dropout_dense_block_two': 0.5019629041961778}
# accuracy=0.9507936239242554
# {'batch_size': 110.0, 'dropout_cnn_block_one': 0.4166478555749807, 'dropout_cnn_block_tree': 0.4045780385795632, 'dropout_cnn_block_two': 0.4876334194126869, 'dropout_dense_block_one': 0.35512280449912653, 'dropout_dense_block_two': 0.5055806844195833}
# accuracy=0.9281179308891296
# {'batch_size': 170.0, 'dropout_cnn_block_one': 0.37508842031226386, 'dropout_cnn_block_tree': 0.37653150679000164, 'dropout_cnn_block_two': 0.3475526370802671, 'dropout_dense_block_one': 0.3307102543808905, 'dropout_dense_block_two': 0.4144966209767381}
# accuracy=0.9596371650695801
# {'batch_size': 110.0, 'dropout_cnn_block_one': 0.3765652321216545, 'dropout_cnn_block_tree': 0.45616037475486615, 'dropout_cnn_block_two': 0.37066546472340667, 'dropout_dense_block_one': 0.43625015764099784, 'dropout_dense_block_two': 0.3838227863944916}
# accuracy=0.9507936239242554
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.4220943972298884, 'dropout_cnn_block_tree': 0.31152351174771387, 'dropout_cnn_block_two': 0.3358154343757738, 'dropout_dense_block_one': 0.3340343959649792, 'dropout_dense_block_two': 0.45091941540475095}
# accuracy=0.960544228553772
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.4251148725656015, 'dropout_cnn_block_tree': 0.3047853753353765, 'dropout_cnn_block_two': 0.3013754176863385, 'dropout_dense_block_one': 0.31233719095059653, 'dropout_dense_block_two': 0.5261263906551876}
# accuracy=0.9655328989028931
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.3833399902223007, 'dropout_cnn_block_tree': 0.4626282720439893, 'dropout_cnn_block_two': 0.30454224164062493, 'dropout_dense_block_one': 0.43258972172455945, 'dropout_dense_block_two': 0.5202011623737403}
# accuracy=0.9691609740257263
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.3031590025700778, 'dropout_cnn_block_tree': 0.467413213077149, 'dropout_cnn_block_two': 0.3688120501915165, 'dropout_dense_block_one': 0.44389105059346423, 'dropout_dense_block_two': 0.5920037437705743}
# accuracy=0.9634920358657837
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.33308780120017856, 'dropout_cnn_block_tree': 0.49716451700762476, 'dropout_cnn_block_two': 0.33191139030476663, 'dropout_dense_block_one': 0.42112926828634367, 'dropout_dense_block_two': 0.5176924114043904}
# accuracy=0.9712018370628357
# 100%|██████████| 30/30 [05:56<00:00, 11.89s/it, best loss: -0.9712018370628357]

# %%
space = {
    'batch_size': hp.quniform('batch_size', 100, 200, 10),
    'dropout_cnn_block_one': hp.uniform('dropout_cnn_block_one', 0.3, 0.5),
    'dropout_cnn_block_two': hp.uniform('dropout_cnn_block_two', 0.3, 0.5),
    'dropout_cnn_block_tree': hp.uniform('dropout_cnn_block_tree', 0.3, 0.5),

    'dropout_dense_block_one': hp.uniform('dropout_dense_block_one', 0.3, 0.7),
    'dropout_dense_block_two': hp.uniform('dropout_dense_block_two', 0.3, 0.7)
}

best = fmin(
    func_obj,
    space,
    tpe.suggest,
    30,
    Trials()
    
)
# Out:
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.38306425692769397, 'dropout_cnn_block_tree': 0.35902224765096513, 'dropout_cnn_block_two': 0.3097515179405164, 'dropout_dense_block_one': 0.43183593122773695, 'dropout_dense_block_two': 0.3782647180359416}
# accuracy=0.9671201705932617
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.40284678334897545, 'dropout_cnn_block_tree': 0.47262121085433884, 'dropout_cnn_block_two': 0.3391935123355201, 'dropout_dense_block_one': 0.34617386500963876, 'dropout_dense_block_two': 0.4734785302262725}
# accuracy=0.9519274234771729
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.35127401991692303, 'dropout_cnn_block_tree': 0.34586536324366396, 'dropout_cnn_block_two': 0.42324503975984484, 'dropout_dense_block_one': 0.41706251690733015, 'dropout_dense_block_two': 0.6808494415250831}
# accuracy=0.9124716520309448
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.35412305783800263, 'dropout_cnn_block_tree': 0.3026291062841846, 'dropout_cnn_block_two': 0.34077269116492914, 'dropout_dense_block_one': 0.32078528960034075, 'dropout_dense_block_two': 0.44108023287429826}
# accuracy=0.9727891087532043
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.4663340844021593, 'dropout_cnn_block_tree': 0.43154767951307293, 'dropout_cnn_block_two': 0.3223687516982803, 'dropout_dense_block_one': 0.3801930440710607, 'dropout_dense_block_two': 0.3737676307816158}
# accuracy=0.9562358260154724
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.3001348882369903, 'dropout_cnn_block_tree': 0.4211963007407076, 'dropout_cnn_block_two': 0.44149766687351366, 'dropout_dense_block_one': 0.5118453314293097, 'dropout_dense_block_two': 0.38475833881848903}
# accuracy=0.961904764175415
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.3054331509236029, 'dropout_cnn_block_tree': 0.3465138268471709, 'dropout_cnn_block_two': 0.4241233952998327, 'dropout_dense_block_one': 0.34996799416144536, 'dropout_dense_block_two': 0.38396181772634125}
# accuracy=0.9727891087532043
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.489813474607908, 'dropout_cnn_block_tree': 0.3098169351605316, 'dropout_cnn_block_two': 0.4690231941717748, 'dropout_dense_block_one': 0.6319521358798683, 'dropout_dense_block_two': 0.380582521068918}
# accuracy=0.9476190209388733
# {'batch_size': 180.0, 'dropout_cnn_block_one': 0.3045528154938523, 'dropout_cnn_block_tree': 0.4066697918046928, 'dropout_cnn_block_two': 0.3836262009073741, 'dropout_dense_block_one': 0.4283806708622286, 'dropout_dense_block_two': 0.3157758240517788}
# accuracy=0.9632652997970581
# {'batch_size': 110.0, 'dropout_cnn_block_one': 0.4081006328680978, 'dropout_cnn_block_tree': 0.32780931806426417, 'dropout_cnn_block_two': 0.3405160506472863, 'dropout_dense_block_one': 0.6673845788970236, 'dropout_dense_block_two': 0.4381225115161629}
# accuracy=0.94399094581604
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.4131841689404031, 'dropout_cnn_block_tree': 0.4136802358121402, 'dropout_cnn_block_two': 0.3144131732518814, 'dropout_dense_block_one': 0.30301317654842264, 'dropout_dense_block_two': 0.41472009626233153}
# accuracy=0.9115646481513977
# {'batch_size': 180.0, 'dropout_cnn_block_one': 0.33474330121284246, 'dropout_cnn_block_tree': 0.45375317560059997, 'dropout_cnn_block_two': 0.33299213233934827, 'dropout_dense_block_one': 0.3672799143978436, 'dropout_dense_block_two': 0.6803266435014225}
# accuracy=0.9442176818847656
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.4651518778252262, 'dropout_cnn_block_tree': 0.4388040281397704, 'dropout_cnn_block_two': 0.3564011154836444, 'dropout_dense_block_one': 0.32871113809128705, 'dropout_dense_block_two': 0.6347724784876811}
# accuracy=0.9181405901908875
# {'batch_size': 180.0, 'dropout_cnn_block_one': 0.4207719844078882, 'dropout_cnn_block_tree': 0.3433347042739659, 'dropout_cnn_block_two': 0.49758994187214045, 'dropout_dense_block_one': 0.6540377198418159, 'dropout_dense_block_two': 0.4957458542727091}
# accuracy=0.9442176818847656
# {'batch_size': 180.0, 'dropout_cnn_block_one': 0.3492705043196716, 'dropout_cnn_block_tree': 0.3643603087477506, 'dropout_cnn_block_two': 0.37694995226832156, 'dropout_dense_block_one': 0.6262880390140513, 'dropout_dense_block_two': 0.6597873402705013}
# accuracy=0.9401360750198364
# {'batch_size': 110.0, 'dropout_cnn_block_one': 0.30764098463959333, 'dropout_cnn_block_tree': 0.489823694335961, 'dropout_cnn_block_two': 0.4100890031357273, 'dropout_dense_block_one': 0.389955267436513, 'dropout_dense_block_two': 0.6591359030344133}
# accuracy=0.9562358260154724
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.3827230480356109, 'dropout_cnn_block_tree': 0.35829615186854225, 'dropout_cnn_block_two': 0.36365411102353146, 'dropout_dense_block_one': 0.3743073173100202, 'dropout_dense_block_two': 0.31737552196430313}
# accuracy=0.9589568972587585
# {'batch_size': 120.0, 'dropout_cnn_block_one': 0.42927658629023546, 'dropout_cnn_block_tree': 0.4905933040883363, 'dropout_cnn_block_two': 0.3773325018969899, 'dropout_dense_block_one': 0.3228407689200705, 'dropout_dense_block_two': 0.3206629078118395}
# accuracy=0.9496598839759827
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.4738526542476945, 'dropout_cnn_block_tree': 0.3204544124390219, 'dropout_cnn_block_two': 0.3057824083231357, 'dropout_dense_block_one': 0.64493987471589, 'dropout_dense_block_two': 0.6009826466604564}
# accuracy=0.88117915391922
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.4925272233632829, 'dropout_cnn_block_tree': 0.4778706202687908, 'dropout_cnn_block_two': 0.37122391444977887, 'dropout_dense_block_one': 0.3248481829735058, 'dropout_dense_block_two': 0.5558573789719222}
# accuracy=0.9324263334274292
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.3289598425060679, 'dropout_cnn_block_tree': 0.3853707234654731, 'dropout_cnn_block_two': 0.4490388014660704, 'dropout_dense_block_one': 0.495715893622382, 'dropout_dense_block_two': 0.5575240432160558}
# accuracy=0.9632652997970581
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.37553150541223906, 'dropout_cnn_block_tree': 0.3042310245418601, 'dropout_cnn_block_two': 0.40027280902288215, 'dropout_dense_block_one': 0.4819436757281178, 'dropout_dense_block_two': 0.45792987792020134}
# accuracy=0.960544228553772
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.3208159474415315, 'dropout_cnn_block_tree': 0.38458099969446885, 'dropout_cnn_block_two': 0.4838218793790637, 'dropout_dense_block_one': 0.5628971572191659, 'dropout_dense_block_two': 0.5308167769991077}
# accuracy=0.9337868690490723
# {'batch_size': 110.0, 'dropout_cnn_block_one': 0.35921917266150033, 'dropout_cnn_block_tree': 0.3302217588682475, 'dropout_cnn_block_two': 0.42384820668943946, 'dropout_dense_block_one': 0.464413929840955, 'dropout_dense_block_two': 0.4200334566130442}
# accuracy=0.9668934345245361
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.3180484267815438, 'dropout_cnn_block_tree': 0.30440965708053047, 'dropout_cnn_block_two': 0.4578449795248059, 'dropout_dense_block_one': 0.5387333559884941, 'dropout_dense_block_two': 0.3477623876678761}
# accuracy=0.9573696255683899
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.3674160944692345, 'dropout_cnn_block_tree': 0.38050480452665025, 'dropout_cnn_block_two': 0.3961744071716853, 'dropout_dense_block_one': 0.3001542242945604, 'dropout_dense_block_two': 0.5044670172045185}
# accuracy=0.9528344869613647
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.344407873895871, 'dropout_cnn_block_tree': 0.3418209104763008, 'dropout_cnn_block_two': 0.4173142780464473, 'dropout_dense_block_one': 0.5877200187531634, 'dropout_dense_block_two': 0.34263724452011257}
# accuracy=0.9591836929321289
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.33613054348143284, 'dropout_cnn_block_tree': 0.3138202130225355, 'dropout_cnn_block_two': 0.43880480228718555, 'dropout_dense_block_one': 0.4055981218893826, 'dropout_dense_block_two': 0.42801875395846106}
# accuracy=0.9362812042236328
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.39401373488489977, 'dropout_cnn_block_tree': 0.36205130582348966, 'dropout_cnn_block_two': 0.3526367722195228, 'dropout_dense_block_one': 0.44838311510204043, 'dropout_dense_block_two': 0.3959637195083238}
# accuracy=0.9544217586517334
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.4484528037076578, 'dropout_cnn_block_tree': 0.3355473630070724, 'dropout_cnn_block_two': 0.3881805876492528, 'dropout_dense_block_one': 0.35278823324524305, 'dropout_dense_block_two': 0.45745777148151395}
# accuracy=0.9068027138710022
# 100%|██████████| 30/30 [08:43<00:00, 17.45s/it, best loss: -0.9727891087532043]
